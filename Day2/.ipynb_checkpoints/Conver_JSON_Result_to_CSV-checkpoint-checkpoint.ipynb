# %%
import pandas as pd

df = pd.read_json(r'result.json')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-2-5182f61d663f> in <module>
#       1 import pandas as pd
#       2
# ----> 3 df = pd.read_json(r'result.json')
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     212                 else:
#     213                     kwargs[new_arg_name] = new_arg_value
# --> 214             return func(*args, **kwargs)
#     215
#     216         return cast(F, wrapper)
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\io\json\_json.py in read_json(path_or_buf, orient, typ, dtype, convert_axes, convert_dates, keep_default_dates, numpy, precise_float, date_unit, encoding, lines, chunksize, compression)
#     606         return json_reader
#     607
# --> 608     result = json_reader.read()
#     609     if should_close:
# ...

# %%
import json

data = json.load(open('result.json'))
df = pd.DataFrame(data['list'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 13 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   dt          7 non-null      int64
#  1   sunrise     7 non-null      int64
#  2   sunset      7 non-null      int64
#  3   temp        7 non-null      object
#  4   feels_like  7 non-null      object
#  5   pressure    7 non-null      int64
#  6   humidity    7 non-null      int64
#  7   weather     7 non-null      object
#  8   speed       7 non-null      float64
#  9   deg         7 non-null      int64
#  10  gust        7 non-null      float64
#  11  clouds      7 non-null      int64
#  12  pop         7 non-null      int64
# dtypes: float64(2), int64(8), object(3)
# memory usage: 856.0+ bytes

# %%
df.head()
# Out:
#            dt     sunrise      sunset  \
# 0  1619082000  1619061630  1619108768
# 1  1619168400  1619147970  1619195206
# 2  1619254800  1619234310  1619281645
# 3  1619341200  1619320652  1619368084
# 4  1619427600  1619406994  1619454523
#
#                                                 temp  \
# 0  {'day': 298.32, 'min': 288.29, 'max': 302.42, ...
# 1  {'day': 299.22, 'min': 288.05, 'max': 304.21, ...
# 2  {'day': 301.39, 'min': 289.04, 'max': 306.36, ...
# 3  {'day': 304.15, 'min': 292.58, 'max': 310.19, ...
# 4  {'day': 298.34, 'min': 289.51, 'max': 302.23, ...
#
#                                           feels_like  pressure  humidity  \
# 0  {'day': 297.81, 'night': 287.74, 'eve': 300.06...      1019        35
# 1  {'day': 299.22, 'night': 287.48, 'eve': 300.66...      1016        22
# 2  {'day': 300.08, 'night': 288.62, 'eve': 302.9,...      1011        21
# 3  {'day': 302.1, 'night': 292.33, 'eve': 307.09,...      1008        15
# ...

# %%
df.to_csv('outputAsCSVFile.csv', index=False)
